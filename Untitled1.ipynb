# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Enrique González Kees**
# Desired ocupation: Business Analyst

# %% [markdown]
# *I am interested in Data Science because I think it is an important area on organizations and it is also important for a professional to understand and being able to manage the Data Science concepts and tools*

# %% [markdown]
# # The code of below make a sum of the numer 3 with the number 3. The output shows the result of the sum.

# %%
3+3
# Out:
# 6

# %% [markdown]
# https://www.cariverplate.com.ar
# ![GettyImages-1450300303.jpg.webp](attachment:0aa32819-a170-4303-b582-1e1d2517bcf6.webp)
# > Blocked code.
